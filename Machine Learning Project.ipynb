# %% [markdown]
# ### Importing Libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
dataset = pd.read_csv("googleplaystore.csv")

# %%
dataset.head()
# Out:
#                                                  App        Category  Rating  \
# 0     Photo Editor & Candy Camera & Grid & ScrapBook  ART_AND_DESIGN     4.1
# 1                                Coloring book moana  ART_AND_DESIGN     3.9
# 2  U Launcher Lite – FREE Live Cool Themes, Hide ...  ART_AND_DESIGN     4.7
# 3                              Sketch - Draw & Paint  ART_AND_DESIGN     4.5
# 4              Pixel Draw - Number Art Coloring Book  ART_AND_DESIGN     4.3
#
#   Reviews  Size     Installs  Type Price Content Rating  \
# 0     159   19M      10,000+  Free     0       Everyone
# 1     967   14M     500,000+  Free     0       Everyone
# 2   87510  8.7M   5,000,000+  Free     0       Everyone
# 3  215644   25M  50,000,000+  Free     0           Teen
# 4     967  2.8M     100,000+  Free     0       Everyone
#
#                       Genres      Last Updated         Current Ver  \
# 0               Art & Design   January 7, 2018               1.0.0
# 1  Art & Design;Pretend Play  January 15, 2018               2.0.0
# 2               Art & Design    August 1, 2018               1.2.4
# 3               Art & Design      June 8, 2018  Varies with device
# 4    Art & Design;Creativity     June 20, 2018                 1.1
#
#     Android Ver
# 0  4.0.3 and up
# 1  4.0.3 and up
# 2  4.0.3 and up
# 3    4.2 and up
# 4    4.4 and up

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10841 entries, 0 to 10840
# Data columns (total 13 columns):
# App               10841 non-null object
# Category          10841 non-null object
# Rating            9367 non-null float64
# Reviews           10841 non-null object
# Size              10841 non-null object
# Installs          10841 non-null object
# Type              10840 non-null object
# Price             10841 non-null object
# Content Rating    10840 non-null object
# Genres            10841 non-null object
# Last Updated      10841 non-null object
# Current Ver       10833 non-null object
# Android Ver       10838 non-null object
# dtypes: float64(1), object(12)
# memory usage: 1.1+ MB

# %%
dataset.dropna(inplace = True)

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 9360 entries, 0 to 10840
# Data columns (total 13 columns):
# App               9360 non-null object
# Category          9360 non-null object
# Rating            9360 non-null float64
# Reviews           9360 non-null object
# Size              9360 non-null object
# Installs          9360 non-null object
# Type              9360 non-null object
# Price             9360 non-null object
# Content Rating    9360 non-null object
# Genres            9360 non-null object
# Last Updated      9360 non-null object
# Current Ver       9360 non-null object
# Android Ver       9360 non-null object
# dtypes: float64(1), object(12)
# memory usage: 1023.8+ KB

# %%
rcParams['figure.figsize'] = 11.7,8.27
g = sns.kdeplot(data.Rating, color="Red", shade = True)
g.set_xlabel("Rating")
g.set_ylabel("Frequency")
plt.title('Distribution of Rating',size = 20)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-67-6b64d1676a78> in <module>()
# ----> 1 rcParams['figure.figsize'] = 11.7,8.27
#       2 g = sns.kdeplot(data.Rating, color="Red", shade = True)
#       3 g.set_xlabel("Rating")
#       4 g.set_ylabel("Frequency")
#       5 plt.title('Distribution of Rating',size = 20)
#
# NameError: name 'rcParams' is not defined

# %%
dataset = dataset.drop(['App'],axis=1)
dataset = dataset.drop(['Genres'],axis=1)
dataset = dataset.drop(['Last Updated'],axis=1)

# %%
dataset.fillna(dataset.mean(), inplace=True)

# %%
dataset.round(2)
# Out:
#                   Category  Rating Reviews                Size     Installs  \
# 0           ART_AND_DESIGN     4.1     159                 19M      10,000+
# 1           ART_AND_DESIGN     3.9     967                 14M     500,000+
# 2           ART_AND_DESIGN     4.7   87510                8.7M   5,000,000+
# 3           ART_AND_DESIGN     4.5  215644                 25M  50,000,000+
# 4           ART_AND_DESIGN     4.3     967                2.8M     100,000+
# 5           ART_AND_DESIGN     4.4     167                5.6M      50,000+
# 6           ART_AND_DESIGN     3.8     178                 19M      50,000+
# 7           ART_AND_DESIGN     4.1   36815                 29M   1,000,000+
# 8           ART_AND_DESIGN     4.4   13791                 33M   1,000,000+
# 9           ART_AND_DESIGN     4.7     121                3.1M      10,000+
# 10          ART_AND_DESIGN     4.4   13880                 28M   1,000,000+
# 11          ART_AND_DESIGN     4.4    8788                 12M   1,000,000+
# 12          ART_AND_DESIGN     4.2   44829                 20M  10,000,000+
# 13          ART_AND_DESIGN     4.6    4326                 21M     100,000+
# 14          ART_AND_DESIGN     4.4    1518                 37M     100,000+
# 16          ART_AND_DESIGN     4.7    3632                5.5M     500,000+
# 17          ART_AND_DESIGN     4.5      27                 17M      10,000+
# 18          ART_AND_DESIGN     4.3  194216                 39M   5,000,000+
# 19          ART_AND_DESIGN     4.6  224399                 31M  10,000,000+
# 20          ART_AND_DESIGN     4.0     450                 14M     100,000+
# 21          ART_AND_DESIGN     4.1     654                 12M     100,000+
# 22          ART_AND_DESIGN     4.7    7699                4.2M     500,000+
# 24          ART_AND_DESIGN     4.7     118                 23M      50,000+
# 25          ART_AND_DESIGN     4.8     192                6.0M      10,000+
# 26          ART_AND_DESIGN     4.7   20260                 25M     500,000+
# 27          ART_AND_DESIGN     4.1     203                6.1M     100,000+
# 28          ART_AND_DESIGN     3.9     136                4.6M      10,000+
# 29          ART_AND_DESIGN     4.1     223                4.2M     100,000+
# 30          ART_AND_DESIGN     4.2    1120                9.2M     100,000+
# 31          ART_AND_DESIGN     4.1     227                5.2M      50,000+
# ...                    ...     ...     ...                 ...          ...
# 10795                TOOLS     4.2    7339                4.0M     100,000+
# 10796                TOOLS     4.7   61445                7.8M   1,000,000+
# 10797            LIFESTYLE     4.6   32433                 46M   1,000,000+
# 10799               SOCIAL     4.7    2036                6.8M     100,000+
# 10800                TOOLS     4.1     174                 12M       5,000+
# 10801               FAMILY     4.9      52                 19M       1,000+
# 10802               FAMILY     4.0     185                 28M      10,000+
# 10803                 GAME     4.3   56496                 81M   1,000,000+
# 10804                 GAME     4.2    5442                 17M     100,000+
# 10805            LIFESTYLE     4.3       3                 15M         100+
# 10809               FAMILY     4.7  376223                 24M   1,000,000+
# 10810             BUSINESS     4.8      19                 21M         100+
# 10812               FAMILY     4.1      80                 13M       1,000+
# 10814               FAMILY     4.0     785                 31M      50,000+
# 10815  BOOKS_AND_REFERENCE     4.2    5775                4.9M     500,000+
# 10817                TOOLS     4.0     885                8.0M     100,000+
# 10819  BOOKS_AND_REFERENCE     3.3      52                3.6M       5,000+
# 10820               FAMILY     5.0      22                8.6M       1,000+
# 10826               SOCIAL     4.0   88486  Varies with device   5,000,000+
# 10827               FAMILY     4.2     117                 13M       5,000+
# 10828               COMICS     3.4     291                 13M      10,000+
# 10829  BOOKS_AND_REFERENCE     4.6     603                7.4M      10,000+
# 10830   NEWS_AND_MAGAZINES     3.8     881                2.3M     100,000+
# 10832              WEATHER     3.8    1195                582k     100,000+
# 10833  BOOKS_AND_REFERENCE     4.8      44                619k       1,000+
# 10834               FAMILY     4.0       7                2.6M         500+
# 10836               FAMILY     4.5      38                 53M       5,000+
# 10837               FAMILY     5.0       4                3.6M         100+
# 10839  BOOKS_AND_REFERENCE     4.5     114  Varies with device       1,000+
# 10840            LIFESTYLE     4.5  398307                 19M  10,000,000+
#
#        Type Price Content Rating         Current Ver         Android Ver
# 0      Free     0       Everyone               1.0.0        4.0.3 and up
# 1      Free     0       Everyone               2.0.0        4.0.3 and up
# 2      Free     0       Everyone               1.2.4        4.0.3 and up
# 3      Free     0           Teen  Varies with device          4.2 and up
# 4      Free     0       Everyone                 1.1          4.4 and up
# 5      Free     0       Everyone                 1.0          2.3 and up
# 6      Free     0       Everyone                 1.1        4.0.3 and up
# 7      Free     0       Everyone            6.1.61.1          4.2 and up
# 8      Free     0       Everyone               2.9.2          3.0 and up
# 9      Free     0       Everyone                 2.8        4.0.3 and up
# 10     Free     0       Everyone               1.0.4          4.1 and up
# 11     Free     0       Everyone              1.0.15          4.0 and up
# 12     Free     0           Teen                 3.8          4.1 and up
# 13     Free     0       Everyone               1.0.4          4.4 and up
# 14     Free     0       Everyone               1.2.3          2.3 and up
# 16     Free     0       Everyone                 3.1          4.1 and up
# 17     Free     0       Everyone                 1.0          2.3 and up
# 18     Free     0       Everyone               2.2.5        4.0.3 and up
# 19     Free     0       Everyone               5.5.4          4.1 and up
# 20     Free     0       Everyone                 4.0          4.1 and up
# 21     Free     0       Everyone                 1.1        4.0.3 and up
# 22     Free     0   Everyone 10+             2.2.6.2        4.0.3 and up
# 24     Free     0       Everyone               1.1.3          4.1 and up
# 25     Free     0       Everyone                 1.5          3.0 and up
# 26     Free     0       Everyone               1.0.8        4.0.3 and up
# 27     Free     0       Everyone                1.03        4.0.3 and up
# 28     Free     0       Everyone                 6.0          2.3 and up
# 29     Free     0       Everyone                 1.0          2.3 and up
# 30     Free     0       Everyone         6.7.12.2018        4.0.3 and up
# 31     Free     0       Everyone                 1.2          2.3 and up
# ...     ...   ...            ...                 ...                 ...
# 10795  Free     0       Everyone                1.74          4.1 and up
# 10796  Free     0       Everyone             1.9.734          4.1 and up
# 10797  Free     0       Everyone               2.9.1          5.0 and up
# 10799  Free     0       Everyone                1.72        4.0.3 and up
# 10800  Free     0       Everyone                6.04          4.4 and up
# 10801  Free     0       Everyone                 1.0          4.4 and up
# 10802  Free     0           Teen               1.3.0          3.0 and up
# 10803  Free     0           Teen             1.5.447          4.0 and up
# 10804  Free     0           Teen               4.1.3          2.3 and up
# 10805  Free     0       Everyone                 2.1          4.2 and up
# 10809  Free     0       Everyone               1.4.2          4.1 and up
# 10810  Free     0       Everyone                 1.0          4.4 and up
# 10812  Free     0       Everyone              2.0.20        4.0.3 and up
# 10814  Free     0           Teen               1.3.1          3.0 and up
# 10815  Free     0       Everyone             7.0.4.6          4.2 and up
# 10817  Free     0       Everyone          1.0.612928          5.0 and up
# 10819  Free     0           Teen               0.3.4          4.1 and up
# 10820  Free     0           Teen               3.8.0          4.1 and up
# 10826  Free     0     Mature 17+  Varies with device  Varies with device
# 10827  Free     0       Everyone              2.0.20        4.0.3 and up
# 10828  Free     0       Everyone               2.0.1          4.0 and up
# 10829  Free     0       Everyone                2.96          4.1 and up
# 10830  Free     0       Everyone                 1.5          1.6 and up
# 10832  Free     0       Everyone                 6.0          2.1 and up
# 10833  Free     0       Everyone                 0.8          2.2 and up
# 10834  Free     0       Everyone               1.0.0          4.1 and up
# 10836  Free     0       Everyone                1.48          4.1 and up
# 10837  Free     0       Everyone                 1.0          4.1 and up
# 10839  Free     0     Mature 17+  Varies with device  Varies with device
# 10840  Free     0       Everyone  Varies with device  Varies with device
#
# [9360 rows x 10 columns]

# %%
dataset.shape
# Out:
# (9360, 10)

# %%
label = dataset['Category']

# %%
dataset = dataset.drop(['Category'],axis=1)

# %%
dataset.isnull().any()
# Out:
# Rating            False
# Reviews           False
# Size              False
# Installs          False
# Type              False
# Price             False
# Content Rating    False
# Current Ver       False
# Android Ver       False
# dtype: bool

# %%
dataset.fillna(dataset.mode, inplace=True)

# %%
from sklearn.preprocessing import LabelEncoder
dataset = dataset.apply(LabelEncoder().fit_transform)

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(dataset, label, test_size = 0.2, random_state = 0)

# %%
from sklearn.metrics import accuracy_score, log_loss
from sklearn.neighbors import KNeighborsClassifier
from sklearn.svm import SVC, LinearSVC, NuSVC
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier, AdaBoostClassifier, GradientBoostingClassifier
from sklearn.naive_bayes import GaussianNB,BernoulliNB,MultinomialNB
from sklearn.discriminant_analysis import LinearDiscriminantAnalysis
from sklearn.linear_model import LinearRegression

classifiers = [
    KNeighborsClassifier(3),
    SVC(kernel="rbf", C=0.025, probability=True),
    DecisionTreeClassifier(),
    RandomForestClassifier(),
    AdaBoostClassifier(),
    GradientBoostingClassifier(),
    GaussianNB(),
    BernoulliNB(),
    MultinomialNB(),
    LinearDiscriminantAnalysis()]

# %%
for clf in classifiers:
    clf.fit(X_train, y_train)
    name = clf.__class__.__name__
    print("="*30)
    print(name)
    
    print('Predicted values')
    train_predictions = clf.predict(X_test)
    print(train_predictions)
    acc = accuracy_score(y_test, train_predictions)
    print("Accuracy: {:.4%}".format(acc))
    
print("="*30)
# Out:
# ==============================
# KNeighborsClassifier
# Predicted values
# ['GAME' 'FAMILY' 'ENTERTAINMENT' ... 'LIFESTYLE' 'AUTO_AND_VEHICLES'
#  'FAMILY']
# Accuracy: 20.4594%
# ==============================
# SVC
# Predicted values
# ['FAMILY' 'FAMILY' 'FAMILY' ... 'FAMILY' 'FAMILY' 'FAMILY']
# Accuracy: 18.0556%
# ==============================
# DecisionTreeClassifier
# Predicted values
# ['GAME' 'FAMILY' 'TOOLS' ... 'COMMUNICATION' 'ENTERTAINMENT' 'LIFESTYLE']
# Accuracy: 30.6090%
# ==============================
# RandomForestClassifier
# Predicted values
# ['GAME' 'FAMILY' 'FAMILY' ... 'SPORTS' 'SOCIAL' 'FAMILY']
# Accuracy: 34.9359%
# ==============================
# AdaBoostClassifier
# Predicted values
# ['DATING' 'FAMILY' 'FAMILY' ... 'FAMILY' 'ENTERTAINMENT' 'FAMILY']
# Accuracy: 14.4765%
# ==============================
# GradientBoostingClassifier
# Predicted values
# ['GAME' 'FAMILY' 'TOOLS' ... 'FAMILY' 'ENTERTAINMENT' 'FAMILY']
# Accuracy: 31.0897%
# ==============================
# GaussianNB
# Predicted values
# ['COMICS' 'LIBRARIES_AND_DEMO' 'LIBRARIES_AND_DEMO' ... 'TOOLS' 'COMICS'
#  'LIBRARIES_AND_DEMO']
# Accuracy: 2.4573%
# ==============================
# BernoulliNB
# Predicted values
# ['FAMILY' 'FAMILY' 'FAMILY' ... 'FAMILY' 'FAMILY' 'FAMILY']
# Accuracy: 18.1624%
# ==============================
# MultinomialNB
# Predicted values
# ['ART_AND_DESIGN' 'GAME' 'MEDICAL' ... 'ART_AND_DESIGN' 'TOOLS'
#  'ART_AND_DESIGN']
# Accuracy: 4.5406%
# ==============================
# LinearDiscriminantAnalysis
# Predicted values
# ['GAME' 'FAMILY' 'FAMILY' ... 'TOOLS' 'DATING' 'FAMILY']
# Accuracy: 21.2073%
# ==============================
